# %%
import pandas as pd
from flask_cors import CORS
from flask import Flask,jsonify,render_template
import datetime

# %%
data = pd.read_csv(r"resources/data.csv")

# %%
app = Flask(__name__)
CORS(app,resources={r"/*": {"origins": ["https://turkishfilms.github.io"]}})

# %%
def add_entry(entry):
    data2 = pd.DataFrame([[value for key,value in entry]],columns=["id","name","territory_number","checkout_date","return_by_date","return_date","completed"])
    data = pd.concat([data,data2])

# %%
def mark_entry_completed():
    pass

# %%
@app.route("/")
def homse():
    return render_template('index.html')

@app.route("/add<entry>")
def nowaybro(entry):
    print("no")
    add_entry(entry)
    return 
    
@app.route('/completed<index>')
def completething(index):
    mark_entry_completed(index)

if(__name__=="__main__"):
    app.run()
# Out:
#  * Serving Flask app '__main__'
#  * Debug mode: off
# WARNING: This is a development server. Do not use it in a production deployment. Use a production WSGI server instead.
#  * Running on http://127.0.0.1:5000
# Press CTRL+C to quit
# [2023-05-21 08:29:10,397] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "d:\programs\python\Lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#                                                 ^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ddram\AppData\Local\Temp\ipykernel_15488\3255292659.py", line 3, in home
#     return render_template('index.html')
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\templating.py", line 150, in render_template
#     template = app.jinja_env.get_or_select_template(template_name_or_list)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\jinja2\environment.py", line 1081, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\jinja2\environment.py", line 1010, in get_template
#     return self._load_template(name, globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\jinja2\environment.py", line 969, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\jinja2\loaders.py", line 126, in load
#     source, filename, uptodate = self.get_source(environment, name)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\templating.py", line 64, in get_source
#     return self._get_source_fast(environment, template)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\templating.py", line 98, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [21/May/2023 08:29:10] "GET / HTTP/1.1" 500 -
# [2023-05-21 08:29:11,756] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "d:\programs\python\Lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#                                                 ^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ddram\AppData\Local\Temp\ipykernel_15488\3255292659.py", line 3, in home
#     return render_template('index.html')
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\templating.py", line 150, in render_template
#     template = app.jinja_env.get_or_select_template(template_name_or_list)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\jinja2\environment.py", line 1081, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\jinja2\environment.py", line 1010, in get_template
#     return self._load_template(name, globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\jinja2\environment.py", line 969, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\jinja2\loaders.py", line 126, in load
#     source, filename, uptodate = self.get_source(environment, name)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\templating.py", line 64, in get_source
#     return self._get_source_fast(environment, template)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\templating.py", line 98, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [21/May/2023 08:29:11] "GET / HTTP/1.1" 500 -
# [2023-05-21 08:29:12,177] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "d:\programs\python\Lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#                                                 ^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ddram\AppData\Local\Temp\ipykernel_15488\3255292659.py", line 3, in home
#     return render_template('index.html')
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\templating.py", line 150, in render_template
#     template = app.jinja_env.get_or_select_template(template_name_or_list)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\jinja2\environment.py", line 1081, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\jinja2\environment.py", line 1010, in get_template
#     return self._load_template(name, globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\jinja2\environment.py", line 969, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\jinja2\loaders.py", line 126, in load
#     source, filename, uptodate = self.get_source(environment, name)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\templating.py", line 64, in get_source
#     return self._get_source_fast(environment, template)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\templating.py", line 98, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [21/May/2023 08:29:12] "GET / HTTP/1.1" 500 -
# [2023-05-21 08:29:12,546] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "d:\programs\python\Lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#                                                 ^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ddram\AppData\Local\Temp\ipykernel_15488\3255292659.py", line 3, in home
#     return render_template('index.html')
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\templating.py", line 150, in render_template
#     template = app.jinja_env.get_or_select_template(template_name_or_list)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\jinja2\environment.py", line 1081, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\jinja2\environment.py", line 1010, in get_template
#     return self._load_template(name, globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\jinja2\environment.py", line 969, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\jinja2\loaders.py", line 126, in load
#     source, filename, uptodate = self.get_source(environment, name)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\templating.py", line 64, in get_source
#     return self._get_source_fast(environment, template)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\templating.py", line 98, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [21/May/2023 08:29:12] "GET / HTTP/1.1" 500 -
# [2023-05-21 08:29:12,906] ERROR in app: Exception on / [GET]
# Traceback (most recent call last):
#   File "d:\programs\python\Lib\site-packages\flask\app.py", line 2190, in wsgi_app
#     response = self.full_dispatch_request()
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\app.py", line 1486, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask_cors\extension.py", line 165, in wrapped_function
#     return cors_after_request(app.make_response(f(*args, **kwargs)))
#                                                 ^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\app.py", line 1484, in full_dispatch_request
#     rv = self.dispatch_request()
#          ^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\app.py", line 1469, in dispatch_request
#     return self.ensure_sync(self.view_functions[rule.endpoint])(**view_args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\ddram\AppData\Local\Temp\ipykernel_15488\3255292659.py", line 3, in home
#     return render_template('index.html')
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\templating.py", line 150, in render_template
#     template = app.jinja_env.get_or_select_template(template_name_or_list)
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\jinja2\environment.py", line 1081, in get_or_select_template
#     return self.get_template(template_name_or_list, parent, globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\jinja2\environment.py", line 1010, in get_template
#     return self._load_template(name, globals)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\jinja2\environment.py", line 969, in _load_template
#     template = self.loader.load(self, name, self.make_globals(globals))
#                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\jinja2\loaders.py", line 126, in load
#     source, filename, uptodate = self.get_source(environment, name)
#                                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\templating.py", line 64, in get_source
#     return self._get_source_fast(environment, template)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "d:\programs\python\Lib\site-packages\flask\templating.py", line 98, in _get_source_fast
#     raise TemplateNotFound(template)
# jinja2.exceptions.TemplateNotFound: index.html
# 127.0.0.1 - - [21/May/2023 08:29:12] "GET / HTTP/1.1" 500 -
